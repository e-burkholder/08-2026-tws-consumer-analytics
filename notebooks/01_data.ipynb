# %% [markdown]
# # 01 Data Collection & Exploration
# ## Table of Contents
# - [Table of Contents](#table-of-contents)
# - [Objectives](#objectives)
# - [Research Questions](#research-questions)
# - [Data Sources]()
# - [Data Loading]()
# - [Data Cleaning]()
# - [Results]()
# - [Analysis]()
# - [Limitations]()
# - [Next Steps]()
#
# ## Objectives
# The objectives of this notebook are to document the process and results of data collection and cleaning in regards to the project.
# - Collect data from public sources
# - Import data for future analysis
# - Clean the data for proper utilization
# - Segment the data into datasets for analysis
# - Analyze the dataset to come to conclusions
# - Describe limitations with this methodology
#
# ## Research Questions
# When considering the objectives of the TWS project, it is vital we determine the target consumers. Since TWS is a pre-established group, debuting in 2024, we can look at previous data insights to determine the initial target market and the actual target audience.
